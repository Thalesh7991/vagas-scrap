# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import datetime
import requests
import json
import datetime

# %%
LINK = "https://portal.gupy.io"
nome_vaga = 'Engenheiro Agrimensor'

def vitrine_vagas_gupy(LINK, nome_vaga):

    print('Abrindo vitrine de vagas')

    driver = webdriver.Chrome()
    driver.get(LINK)
    driver.maximize_window()

    try:
        cuidado_golpes = driver.find_element(By.XPATH, '//*[@id="radix-0"]/div[2]/button')
        cuidado_golpes.click()
    except:
        pass

    search = driver.find_element(By.XPATH, '//*[@id="undefined-input"]')
    search.send_keys(nome_vaga)
    search.send_keys(Keys.ENTER)

    SCROLL_PAUSE_TIME = 0.5

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    print('Vitrine completa!')
    return driver.find_elements(By.XPATH, '//*[@id="main-content"]/ul/li/div')

def coleta_dados_basicos_vagas(vitrine_de_vagas):

    print('Coletando dados das vagas pela vitrine')

    lista_vagas = []

    for vaga in vitrine_de_vagas:
        dict_aux = {}
        try:
            dict_aux['link'] = vaga.find_element(By.TAG_NAME,'a').get_attribute('href')
        except:
            dict_aux['link'] = np.nan

        dict_aux['data_coleta'] = datetime.datetime.now().strftime('%Y-%m-%d')
        
        try:
            dict_aux['titulo_vaga'] = vaga.find_element(By.XPATH,'a/div/h3').get_attribute('innerHTML')
        except:
            dict_aux['titulo_vaga'] = np.nan
        try:
            dict_aux['localidade'] = vaga.find_element(By.XPATH,'//span[@data-testid="job-location"]').get_attribute('innerHTML')
        except:
            dict_aux['localidade'] = np.nan
        try:
            dict_aux['modalidade'] = vaga.find_element(By.XPATH,'a/div/div[2]/div[2]/span').get_attribute('innerHTML')
        except:
            dict_aux['modalidade'] = np.nan
        try:
            dict_aux['contrato'] = vaga.find_element(By.XPATH,'a/div/div[2]/div[3]/span').get_attribute('innerHTML')
        except:
            dict_aux['contrato'] = np.nan
        try:
            dict_aux['pcd'] = vaga.find_element(By.XPATH,'a/div/div[2]/div[4]/span').get_attribute('innerHTML')
        except:
            dict_aux['pcd'] = np.nan

        lista_vagas.append(dict_aux)
    
    print('Dados da vitrine coletados!')

    return pd.DataFrame(lista_vagas)

def coleta_info_vagas(links):

    print('Coletando informações das vagas individualmente')

    lista_vagas = []

    for link in links:

        try:

            dict_aux = {}
            driver = webdriver.Chrome()
            driver.get(link)
            driver.maximize_window()

            try:
                aceitar_cookies = driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]')
                aceitar_cookies.click()
            except:
                pass

            try:
                cuidado_golpes = driver.find_element(By.XPATH, '//*[@id="radix-0"]/div[2]/button')
                cuidado_golpes.click()
            except:
                pass

            try:

                json_vaga = driver.find_element(By.XPATH,'//*[@id="__NEXT_DATA__"]').get_attribute('innerHTML')

                json_vaga = json.loads(json_vaga)

                try:
                    dict_aux['link'] = link
                except:
                    dict_aux['link'] = np.nan   
                try:
                    dict_aux['nome_empresa'] = json_vaga['props']['pageProps']['job']['careerPage']['name']
                except:
                    dict_aux['nome_empresa'] = np.nan     
                try:
                    dict_aux['codigo_vaga'] = json_vaga['props']['pageProps']['job']['id']
                except:
                    dict_aux['codigo_vaga'] = np.nan
                try:
                    dict_aux['data_publicacao'] = json_vaga['props']['pageProps']['job']['publishedAt']
                except:
                    dict_aux['data_publicacao'] = np.nan
                try:
                    dict_aux['data_expiracao'] = json_vaga['props']['pageProps']['job']['expiresAt']
                except:
                    dict_aux['data_expiracao'] = np.nan
                try:
                    dict_aux['descricao'] = json_vaga['props']['pageProps']['job']['description']
                except:
                    dict_aux['descricao'] = np.nan
                try:
                    dict_aux['pre_requisitos'] = json_vaga['props']['pageProps']['job']['prerequisites']
                except:
                    dict_aux['pre_requisitos'] = np.nan
                try:
                    dict_aux['responsabilidades'] = json_vaga['props']['pageProps']['job']['responsibilities']
                except:
                    dict_aux['responsabilidades'] = np.nan
                try:
                    dict_aux['experiencias_relevantes'] = json_vaga['props']['pageProps']['job']['relevantExperiences']
                except:
                    dict_aux['experiencias_relevantes'] = np.nan
                try: 
                    dict_aux['cidade'] = json_vaga['props']['pageProps']['job']['addressCity']
                except:
                    dict_aux['cidade']
                try:
                    dict_aux['estado'] = json_vaga['props']['pageProps']['job']['addressState']
                except:
                    dict_aux['estado'] = np.nan

                lista_vagas.append(dict_aux)

            except:
                pass
        except:
            pass

        print(f'Progresso: {round(links.index(link)/len(links),2)*100} %')

        driver.quit()

    return pd.DataFrame(lista_vagas)

# %%
df_vagas_full = pd.DataFrame()

['topógrago', 'geoprocessamento']

for nome_vaga in ['topógrago', 'geoprocessamento']:

    vitrine_de_vagas = vitrine_vagas_gupy(LINK, nome_vaga)

    df_vagas1 = coleta_dados_basicos_vagas(vitrine_de_vagas)

    df_vagas2 = coleta_info_vagas(df_vagas1['link'].tolist())

    df_vagas = pd.merge(df_vagas1, df_vagas2, on='link', how='left')
    df_vagas['posicao'] = nome_vaga

    df_vagas_full = pd.concat([df_vagas_full, df_vagas], axis=0)

df_vagas_full = df_vagas_full.reset_index(drop=True)

df_vagas_full.to_excel('../data/data_raw/vagas_gupy_raw.xlsx', index = False)
# Out:
# Abrindo vitrine de vagas
# Vitrine completa!
# Coletando dados das vagas pela vitrine
# Dados da vitrine coletados!
# Coletando informações das vagas individualmente
# Progresso: 0.0 %
# Progresso: 8.0 %

# %%
df_vagas_full
# Out:
#                                                  link data_coleta  \
# 0   https://strata.gupy.io/job/eyJqb2JJZCI6NzgxMjQ...  2024-09-24
# 1   https://vagaspontal.gupy.io/job/eyJqb2JJZCI6Nz...  2024-09-24
# 2   https://genteraizen.gupy.io/job/eyJqb2JJZCI6Nz...  2024-09-24
# 3   https://grupoitajobi.gupy.io/job/eyJqb2JJZCI6N...  2024-09-24
# 4   https://cacaushow.gupy.io/job/eyJqb2JJZCI6NzY3...  2024-09-24
# 5   https://strata.gupy.io/job/eyJqb2JJZCI6NzY1MjY...  2024-09-24
# 6   https://genteraizen.gupy.io/job/eyJqb2JJZCI6Nz...  2024-09-24
# 7   https://genteraizen.gupy.io/job/eyJqb2JJZCI6Nz...  2024-09-24
# 8   https://ozminerals.gupy.io/job/eyJqb2JJZCI6NzM...  2024-09-24
# 9   https://ambipar.gupy.io/job/eyJqb2JJZCI6NzM5OT...  2024-09-24
# 10  https://nucleoengenharia.gupy.io/job/eyJqb2JJZ...  2024-09-24
#
#                                titulo_vaga          localidade  modalidade  \
# 0                                TOPÓGRAFO  Belo Horiz... - MG         NaN
# 1                  Auxiliar de topografia   Belo Horiz... - MG         NaN
# 2   Topógrafo Pleno - Vaga também para PcD  Belo Horiz... - MG         NaN
# 3                Topógrafo - Inhumas / GO   Belo Horiz... - MG         NaN
# 4                               Topografo   Belo Horiz... - MG         NaN
# 5                  Auxiliar de Topografia   Belo Horiz... - MG         NaN
# 6                             Topógrafo Sr  Belo Horiz... - MG         NaN
# 7                          Topógrafo(a) Pl  Belo Horiz... - MG         NaN
# 8                         Topógrafo Sênior  Belo Horiz... - MG         NaN
# 9          AMBIPAR RESPONSE ES - Topógrafo  Belo Horiz... - MG         NaN
# 10     Inspetor de Topografia - Planura/MG  Belo Horiz... - MG         NaN
#
#     contrato  pcd                               nome_empresa  codigo_vaga  \
# 0        NaN  NaN                          STRATA ENGENHARIA      7812451
# 1        NaN  NaN                         Construtora Pontal      7784428
# 2        NaN  NaN                                     Raízen      7722519
# 3        NaN  NaN  Grupo Itajobi - Unidades Carolo e Itajobi      7655245
# 4        NaN  NaN                                 Cacau Show      7677715
# 5        NaN  NaN                          STRATA ENGENHARIA      7652619
# 6        NaN  NaN                                     Raízen      7570561
# 7        NaN  NaN                                     Raízen      7514321
# 8        NaN  NaN                         OZ Minerals Brasil      7334418
# 9        NaN  NaN                    Ambipar Response ES S/A      7399721
# 10       NaN  NaN          NÚCLEO ENGENHARIA CONSULTIVA S.A.      7230842
#
#              data_publicacao data_expiracao  \
# 0   2024-09-16T11:50:40.635Z     2024-10-18
# 1   2024-09-10T16:26:45.967Z     2025-03-31
# 2   2024-09-09T12:05:27.196Z     2025-01-09
# 3   2024-09-05T14:09:12.031Z     2024-09-30
# 4   2024-08-22T20:02:03.005Z     2024-09-11
# 5   2024-08-19T13:46:03.165Z     2024-09-19
# 6   2024-08-06T11:38:27.665Z     2025-09-02
# 7   2024-07-25T19:59:23.264Z     2025-08-22
# 8   2024-07-24T20:34:45.337Z     2024-09-30
# 9   2024-07-02T16:59:49.903Z     2024-08-02
# 10  2024-05-28T13:25:40.266Z     2024-11-04
#
#                                             descricao  \
# 0   <p><span style="background-color: rgb(249, 249...
# 1   <p>Você deseja fazer parte de uma empresa que ...
# 2   <p>&nbsp;Quer fazer parte de<strong>&nbsp;um t...
# 3   <p>Buscamos por profissionais qualificados, en...
# 4   <p>Quer fazer parte da nossa turma?</p><p><br>...
# 5   <p>A Strata é reconhecida por desenvolver proj...
# 6   <p>Aqui na Raízen, você une inovação e sustent...
# 7   <p>Aqui na Raízen, você une inovação e sustent...
# 8   <p>A OZ Minerals é uma empresa de mineração mo...
# 9   <p>Olá!</p><p>&nbsp;</p><p>Essa oportunidade é...
# 10  <ul><li>Profissional com experiência na área d...
#
#                                        pre_requisitos  \
# 0   <ul><li class="ql-align-justify">Desejável cur...
# 1   <ul><li>É necessário ter no mínimo <strong>sei...
# 2   <p><span style="color: rgb(10, 10, 35);">🔎</sp...
# 3   <p>Ensino Superior em Agrimensura, Agronomia e...
# 4   <ul><li><span style="color: black;">Ensino Méd...
# 5   <p>·&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;...
# 6   <p><span style="color: rgb(10, 10, 35);">🔎</sp...
# 7   <p><span style="color: rgb(10, 10, 35);">🔎</sp...
# 8   <p>·&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;...
# 9   <ul><li>Formação em Técnico de Agrimensura, Ed...
# 10  <ul><li>Formação de nível técnico completo ;</...
#
#                                     responsabilidades  \
# 0   <p>Você realizará levantamentos topográficos, ...
# 1   <p>Um auxiliar de topografia é um profissional...
# 2   <p><span style="color: rgb(10, 10, 35);">🎯</sp...
# 3   <p class="ql-align-justify">&nbsp;</p><ul><li ...
# 4   <ul><li>Efetuar o reconhecimento básico da áre...
# 5   <p class="ql-align-justify">Auxiliar os profis...
# 6   <p><span style="color: rgb(10, 10, 35);">🎯</sp...
# 7   <p><span style="color: rgb(10, 10, 35);">🎯</sp...
# 8   <p><span style="color: black;">• Efetuar atual...
# 9   <ul><li>Executar levantamentos topográficos, p...
# 10  <ul><li class="ql-align-justify">Acompanhar as...
#
#                               experiencias_relevantes              cidade  \
# 0   <p>Vale alimentação ou refeição de R$ 38,26 po...      Belo Horizonte
# 1   <ul><li>R$ 2.125,00.</li><li>Plano de saúde;&n...          Brumadinho
# 2   <p><strong style="color: rgb(120, 30, 119);">E...             Caarapó
# 3   <p>Salário compatível com o mercado</p><p>Rest...             Inhumas
# 4                                         <p><br></p>             Itapevi
# 5   <p>Vale alimentação ou refeição</p><p>Seguro d...      Belo Horizonte
# 6   <p><strong style="color: rgb(120, 30, 119);">E...         Morro Agudo
# 7   <p><strong style="color: rgb(120, 30, 119);">E...           Andradina
# 8   <p>Residir ou ter disponibilidade para residir...  Água Azul do Norte
# 9   <p><strong>Você contará ainda com estes benefí...          Ouro Preto
# 10  <ul><li>Local de trabalho: Planura/MG;</li><li...             Planura
#
#                 estado    posicao
# 0         Minas Gerais  topógrafo
# 1         Minas Gerais  topógrafo
# 2   Mato Grosso do Sul  topógrafo
# 3                Goiás  topógrafo
# 4            São Paulo  topógrafo
# 5         Minas Gerais  topógrafo
# 6            São Paulo  topógrafo
# 7            São Paulo  topógrafo
# 8                 Pará  topógrafo
# 9         Minas Gerais  topógrafo
# 10        Minas Gerais  topógrafo

# %%
df_vagas_full.to_excel('../data/data_raw/vagas_gupy_raw.xlsx', index = False)

# %%
df_vagas_full.columns
# Out:
# Index(['link', 'titulo_da_vaga', 'localidade', 'modalidade', 'contrato', 'pcd',
#        'codigo_vaga', 'data_publicacao', 'data_expiracao', 'descricao',
#        'pre_requisitos', 'responsabilidades', 'experiencias_relevantes',
#        'cidade', 'estado', 'posicao'],
#       dtype='object')

# %%
df_vagas_full.columns = ['link', 'titulo_da_vaga', 'localidade', 'modalidade', 'contrato', 'pcd',
       'codigo_vaga', 'data_publicacao', 'data_expiracao', 'descricao',
       'pre_requisitos', 'responsabilidades', 'experiencias_relevantes',
       'cidade', 'estado', 'posicao']

# %%
def coleta_info_vagas(links):
    lista_vagas = []

    for link in links:

        print(link)

        dict_aux = {}
        driver = webdriver.Chrome()
        driver.get(link)
        driver.maximize_window()

        try:
            aceitar_cookies = driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]')
            aceitar_cookies.click()
        except:
            pass

        try:
            cuidado_golpes = driver.find_element(By.XPATH, '//*[@id="radix-0"]/div[2]/button')
            cuidado_golpes.click()
        except:
            pass

        try:

            json_vaga = driver.find_element(By.XPATH,'//*[@id="__NEXT_DATA__"]').get_attribute('innerHTML')

            json_vaga = json.loads(json_vaga)

            try:
                dict_aux['link'] = link
            except:
                dict_aux['link'] = np.nan        
            try:
                dict_aux['codigo_vaga'] = json_vaga['props']['pageProps']['job']['id']
            except:
                dict_aux['codigo_vaga'] = np.nan
            try:
                dict_aux['data_publicacao'] = json_vaga['props']['pageProps']['job']['publishedAt']
            except:
                dict_aux['data_publicacao'] = np.nan
            try:
                dict_aux['data_expiracao'] = json_vaga['props']['pageProps']['job']['expiresAt']
            except:
                dict_aux['data_expiracao'] = np.nan
            try:
                dict_aux['descricao'] = json_vaga['props']['pageProps']['job']['description']
            except:
                dict_aux['descricao'] = np.nan
            try:
                dict_aux['pre_requisitos'] = json_vaga['props']['pageProps']['job']['prerequisites']
            except:
                dict_aux['pre_requisitos'] = np.nan
            try:
                dict_aux['responsabilidades'] = json_vaga['props']['pageProps']['job']['responsibilities']
            except:
                dict_aux['responsabilidades'] = np.nan
            try:
                dict_aux['experiencias_relevantes'] = json_vaga['props']['pageProps']['job']['relevantExperiences']
            except:
                dict_aux['experiencias_relevantes'] = np.nan
            try: 
                dict_aux['cidade'] = json_vaga['props']['pageProps']['job']['addressCity']
            except:
                dict_aux['cidade']
            try:
                dict_aux['estado'] = json_vaga['props']['pageProps']['job']['addressState']
            except:
                dict_aux['estado'] = np.nan

            lista_vagas.append(dict_aux)

        except:
            pass

        driver.quit()

# %%
df_vagas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_vagas
#
# NameError: name 'df_vagas' is not defined

# %%
round(df_info_vagas['link'].tolist().index('https://nuclea.gupy.io/job/eyJqb2JJZCI6Njk1MTA1OSwic291cmNlIjoiZ3VweV9wb3J0YWwifQ==?jobBoardSource=gupy_portal')/len(df_info_vagas['link'].tolist()),2)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 round(df_info_vagas['link'].tolist().index('https://nuclea.gupy.io/job/eyJqb2JJZCI6Njk1MTA1OSwic291cmNlIjoiZ3VweV9wb3J0YWwifQ==?jobBoardSource=gupy_portal')/len(df_info_vagas['link'].tolist()),2)*100
#
# NameError: name 'df_info_vagas' is not defined

# %%
df_info_vagas = pd.DataFrame(lista_vagas2)
df_info_vagas
# Out:
#                                                  link  codigo_vaga  \
# 0   https://stefanini.gupy.io/job/eyJqb2JJZCI6Njk5...      6996672
# 1   https://bancosofisa.gupy.io/job/eyJqb2JJZCI6Nj...      6983660
# 2   https://vemprabip.gupy.io/job/eyJqb2JJZCI6Njk4...      6989597
# 3   https://algartelecom.gupy.io/job/eyJqb2JJZCI6N...      6961243
# 4   https://mutantbrvagas.gupy.io/job/eyJqb2JJZCI6...      6986643
# ..                                                ...          ...
# 65  https://bild.gupy.io/job/eyJqb2JJZCI6NTMzMzg0N...      5333845
# 66  https://a3data.gupy.io/job/eyJqb2JJZCI6NDgwNzU...      4807510
# 67  https://slcmaquinas.gupy.io/job/eyJqb2JJZCI6ND...      4456673
# 68  https://dexco.gupy.io/job/eyJqb2JJZCI6MTYwNzA3...      1607079
# 69  https://brivia.gupy.io/job/eyJqb2JJZCI6OTQxMTE...       941110
#
#              data_publicacao data_expiracao  \
# 0   2024-04-08T23:28:00.822Z     2024-04-30
# 1   2024-04-08T14:46:32.051Z     2024-05-10
# 2   2024-04-08T13:53:32.256Z     2024-05-08
# 3   2024-04-08T12:01:17.485Z     2024-04-08
# 4   2024-04-05T17:52:22.645Z     2024-04-30
# ..                       ...            ...
# 65  2023-08-24T14:59:50.237Z     2023-09-11
# 66  2023-05-15T20:07:19.851Z     2023-12-31
# 67  2023-03-15T17:16:23.137Z     2023-04-15
# 68  2022-03-17T20:58:41.000Z     2023-12-31
# 69  2021-06-04T22:19:29.000Z     2024-06-04
#
#                                             descricao  \
# 0   <p><span style="color: black;">📢 Oportunidade ...
# 1   <p><strong>Qual perfil buscamos?</strong></p><...
# 2   <p>Buscamos um cientista de dados com experiên...
# 3   <p><span style="color: rgb(0, 0, 0);">Executar...
# 4   <p><strong>O QUE É SER UM MUTANT?</strong></p>...
# ..                                                ...
# 65  <p><strong style="color: rgb(55, 65, 81);">Sob...
# 66  <p class="ql-align-justify"><span style="color...
# 67  <p>Vem fazer parte de uma empresa Top Ser Huma...
# 68  <p class="ql-align-justify"><span style="color...
# 69  <p>Vaga para nosso BANCO DE TALENTOS</p><p><br...
#
#                                        pre_requisitos  \
# 0                              <p><br></p><p><br></p>
# 1   <ul><li>Experiência com base de dados</li><li>...
# 2   <p><strong>Formação:</strong></p><ul><li>Super...
# 3   <ul><li>Sólidos conhecimentos de programação e...
# 4   <ul><li>Desenvolvimento em Python;</li><li>SQL...
# ..                                                ...
# 65  <ul><li>Experiência sólida em desenvolvimento ...
# 66  <p class="ql-align-justify"><strong style="col...
# 67  <ul><li class="ql-align-justify"><span style="...
# 68  <p>• Desenvolvimento e expansão de nosso DataL...
# 69  <ul><li><span style="color: rgb(0, 0, 0);">Con...
#
#                                     responsabilidades  \
# 0   <p><span style="color: black;">🔎 Estamos procu...
# 1   <p><span style="color: rgba(0, 0, 0, 0.9);">Re...
# 2   <p><strong>Principais atividades:</strong></p>...
# 3   <ul><li>Elabora metodologias de cálculo para a...
# 4   <ul><li>Responsável pelo desenvolvimento de es...
# ..                                                ...
# 65  <ul><li>Desenvolver soluções inovadoras em Pyt...
# 66  <p>P<span style="color: black;">ara ser uma </...
# 67  <ul><li class="ql-align-justify">Coletar grand...
# 68  <p>• Atuar como cientis de dados na evolução e...
# 69  <ul><li><span style="color: rgba(0, 0, 0, 0.87...
#
#                               experiencias_relevantes          cidade  \
# 0   <p><strong>O que te oferecemos:</strong></p><p...
# 1   <p>Será um diferencial:</p><p><br></p><ul><li>...       São Paulo
# 2   <p><strong>CONHEÇA NOSSOS BENEFÍCIOS</strong><...
# 3   <p>Vale refeição</p><p>Assistência Médica</p><...      Uberlândia
# 4   <p><strong>O que você vai encontrar por aqui:<...          Osasco
# ..                                                ...             ...
# 65  <ul><li>Faça parte de uma equipe dinâmica e co...  Ribeirão Preto
# 66  <p class="ql-align-justify"><strong style="col...  Belo Horizonte
# 67  <p><strong>Benefícios:</strong></p><ul><li>Pla...
# 68  <p>• Conhecimentos específicos e obrigatórios:...       São Paulo
# 69  <p>Os desbravadores tem:</p><ul><li>Horário fl...   Florianópolis
#
#             estado
# 0
# 1        São Paulo
# 2
# 3     Minas Gerais
# 4        São Paulo
# ..             ...
# 65       São Paulo
# 66    Minas Gerais
# 67            None
# 68       São Paulo
# 69  Santa Catarina
#
# [70 rows x 10 columns]

# %%
pd.merge(df_vagas, df_info_vagas, on = 'link', how = 'left')
# Out:
#                                                  link  \
# 0   https://stefanini.gupy.io/job/eyJqb2JJZCI6Njk5...
# 1   https://bancosofisa.gupy.io/job/eyJqb2JJZCI6Nj...
# 2   https://vemprabip.gupy.io/job/eyJqb2JJZCI6Njk4...
# 3   https://algartelecom.gupy.io/job/eyJqb2JJZCI6N...
# 4   https://mutantbrvagas.gupy.io/job/eyJqb2JJZCI6...
# ..                                                ...
# 67  https://a3data.gupy.io/job/eyJqb2JJZCI6NDgwNzU...
# 68  https://slcmaquinas.gupy.io/job/eyJqb2JJZCI6ND...
# 69  https://vagasewave.gupy.io/job/eyJqb2JJZCI6Mzk...
# 70  https://dexco.gupy.io/job/eyJqb2JJZCI6MTYwNzA3...
# 71  https://brivia.gupy.io/job/eyJqb2JJZCI6OTQxMTE...
#
#                                        titulo_da_vaga     Localidade  \
# 0                            Cientista de Dados PL/SR  Não informado
# 1                                  Cientista de Dados  Não informado
# 2                     Pessoa Cientista de Dados Pleno  Não informado
# 3                          Pessoa Cientista de Dados   Não informado
# 4                          Cientista de Dados Sênior   Não informado
# ..                                                ...            ...
# 67  Banco de Talentos - Pessoa Cientista de Dados ...  Não informado
# 68                            Cientista de Dados Agro  Não informado
# 69                                 Cientista de Dados  Não informado
# 70            Banco de Talentos - Cientista de Dados   Não informado
# 71                                 Cientista de Dados  Não informado
#
#     Modalidade           Contrato            PDC  codigo_vaga  \
# 0       Remoto            Efetivo  Também p/ PcD    6996672.0
# 1      Híbrido            Efetivo  Também p/ PcD    6983660.0
# 2       Remoto            Efetivo  Também p/ PcD    6989597.0
# 3      Híbrido          Associado  Também p/ PcD    6961243.0
# 4      Híbrido            Efetivo  Também p/ PcD    6986643.0
# ..         ...                ...            ...          ...
# 67      Remoto  Banco de Talentos  Também p/ PcD    4807510.0
# 68  Presencial            Efetivo  Também p/ PcD    4456673.0
# 69      Remoto            Efetivo            NaN          NaN
# 70      Remoto  Banco de Talentos  Também p/ PcD    1607079.0
# 71      Remoto  Banco de Talentos  Também p/ PcD     941110.0
#
#              data_publicacao data_expiracao  \
# 0   2024-04-08T23:28:00.822Z     2024-04-30
# 1   2024-04-08T14:46:32.051Z     2024-05-10
# 2   2024-04-08T13:53:32.256Z     2024-05-08
# 3   2024-04-08T12:01:17.485Z     2024-04-08
# 4   2024-04-05T17:52:22.645Z     2024-04-30
# ..                       ...            ...
# 67  2023-05-15T20:07:19.851Z     2023-12-31
# 68  2023-03-15T17:16:23.137Z     2023-04-15
# 69                       NaN            NaN
# 70  2022-03-17T20:58:41.000Z     2023-12-31
# 71  2021-06-04T22:19:29.000Z     2024-06-04
#
#                                             descricao  \
# 0   <p><span style="color: black;">📢 Oportunidade ...
# 1   <p><strong>Qual perfil buscamos?</strong></p><...
# 2   <p>Buscamos um cientista de dados com experiên...
# 3   <p><span style="color: rgb(0, 0, 0);">Executar...
# 4   <p><strong>O QUE É SER UM MUTANT?</strong></p>...
# ..                                                ...
# 67  <p class="ql-align-justify"><span style="color...
# 68  <p>Vem fazer parte de uma empresa Top Ser Huma...
# 69                                                NaN
# 70  <p class="ql-align-justify"><span style="color...
# 71  <p>Vaga para nosso BANCO DE TALENTOS</p><p><br...
#
#                                        pre_requisitos  \
# 0                              <p><br></p><p><br></p>
# 1   <ul><li>Experiência com base de dados</li><li>...
# 2   <p><strong>Formação:</strong></p><ul><li>Super...
# 3   <ul><li>Sólidos conhecimentos de programação e...
# 4   <ul><li>Desenvolvimento em Python;</li><li>SQL...
# ..                                                ...
# 67  <p class="ql-align-justify"><strong style="col...
# 68  <ul><li class="ql-align-justify"><span style="...
# 69                                                NaN
# 70  <p>• Desenvolvimento e expansão de nosso DataL...
# 71  <ul><li><span style="color: rgb(0, 0, 0);">Con...
#
#                                     responsabilidades  \
# 0   <p><span style="color: black;">🔎 Estamos procu...
# 1   <p><span style="color: rgba(0, 0, 0, 0.9);">Re...
# 2   <p><strong>Principais atividades:</strong></p>...
# 3   <ul><li>Elabora metodologias de cálculo para a...
# 4   <ul><li>Responsável pelo desenvolvimento de es...
# ..                                                ...
# 67  <p>P<span style="color: black;">ara ser uma </...
# 68  <ul><li class="ql-align-justify">Coletar grand...
# 69                                                NaN
# 70  <p>• Atuar como cientis de dados na evolução e...
# 71  <ul><li><span style="color: rgba(0, 0, 0, 0.87...
#
#                               experiencias_relevantes          cidade  \
# 0   <p><strong>O que te oferecemos:</strong></p><p...
# 1   <p>Será um diferencial:</p><p><br></p><ul><li>...       São Paulo
# 2   <p><strong>CONHEÇA NOSSOS BENEFÍCIOS</strong><...
# 3   <p>Vale refeição</p><p>Assistência Médica</p><...      Uberlândia
# 4   <p><strong>O que você vai encontrar por aqui:<...          Osasco
# ..                                                ...             ...
# 67  <p class="ql-align-justify"><strong style="col...  Belo Horizonte
# 68  <p><strong>Benefícios:</strong></p><ul><li>Pla...
# 69                                                NaN             NaN
# 70  <p>• Conhecimentos específicos e obrigatórios:...       São Paulo
# 71  <p>Os desbravadores tem:</p><ul><li>Horário fl...   Florianópolis
#
#             estado
# 0
# 1        São Paulo
# 2
# 3     Minas Gerais
# 4        São Paulo
# ..             ...
# 67    Minas Gerais
# 68            None
# 69             NaN
# 70       São Paulo
# 71  Santa Catarina
#
# [72 rows x 15 columns]

# %%
import json

json_vaga = driver.find_element(By.XPATH,'//*[@id="__NEXT_DATA__"]').get_attribute('innerHTML')


json_vaga = json.loads(json_vaga)
json_vaga['props']['pageProps']['job']['id']
json_vaga['props']['pageProps']['job']['description']
json_vaga['props']['pageProps']['job']['publishedAt']
json_vaga['props']['pageProps']['job']['expiresAt']
json_vaga['props']['pageProps']['job']['description']
json_vaga['props']['pageProps']['job']['prerequisites']
json_vaga['props']['pageProps']['job']['responsibilities']
json_vaga['props']['pageProps']['job']['relevantExperiences']
json_vaga['props']['pageProps']['job']['addressCity']
json_vaga['props']['pageProps']['job']['addressState']
# Out:
# '<p><strong>O que te oferecemos:</strong></p><p><br></p><p><span style="color: rgba(0, 0, 0, 0.9);">🍛 </span><span style="color: black;">Vale Alimentação ou Vale Refeição;</span></p><p>👨🏼\u200d🎓 <span style="color: black;">Desconto em cursos, universidades e instituições de idiomas; </span></p><p><span style="color: rgba(0, 0, 0, 0.9);">📚 </span><span style="color: black;">Academia Stefanini - plataforma com cursos online, gratuitos, atualizados e com certificado; </span></p><p><span style="color: rgba(0, 0, 0, 0.9);">🗣 </span><span style="color: black;">Mentoring;</span></p><p>🏫 <span style="color: black;">Auxílio Creche; </span></p><p>💉 <span style="color: black;">Clube de vantagens para consultas e exames;</span></p><p>🏥 <span style="color: black;">Assistência Médica;</span></p><p>🦷<span style="color: black;">Assistência Odontológica; </span></p><p>💰 <span style="color: black;">Clube de vantagens e descontos nos melhores estabelecimentos;</span></p><p>👂🏾<span style="color: rgba(0, 0, 0, 0.9);"> </span><span style="color: black;">Atendimento psicológico online ao colaborador e seus dependentes;</span></p><p>🛫 <span style="color: black;">Clube de viagens;</span></p><p>🐶 <span style="color: black;">Convênio para Pet;</span></p><p><span style="color: black;">e muito mais...</span></p>'

# %%
def clean_tags(text):
    soup = BeautifulSoup(text, 'html.parser')
    clean_text = soup.get_text()
    return clean_text

clean_tags(json_vaga['props']['pageProps']['job']['description'])
# Out:
# '📢 Oportunidade para\xa0Cientista de Dados PL/SR!Home Office\ufeffEi, você já pensou em fazer parte de um time que só vem crescendo? 🚀Somos a maior multinacional brasileira e estamos entre as 100 maiores empresas de TI do mundo.Estamos presentes em 41 países com +30k colaboradores. A Stefanini tem como principal objetivo auxiliar os clientes a encontrar, por meio de soluções personalizadas, a maneira ideal para alcançar seus desafios, impulsionando a inovação digital.E queremos mais!🤩'
